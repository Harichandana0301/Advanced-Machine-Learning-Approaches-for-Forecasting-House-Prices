# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import warnings
warnings.filterwarnings('ignore')

# Sample data
data = pd.read_csv('Houseprice.csv')
data
# Out:
#             Date  Region ID     Region Name Region Type State Name  \
# 0        7/31/03     395162  Torrington, CT         msa         CT
# 1        8/31/03     395162  Torrington, CT         msa         CT
# 2        9/30/03     395162  Torrington, CT         msa         CT
# 3       10/31/03     395162  Torrington, CT         msa         CT
# 4       11/30/03     395162  Torrington, CT         msa         CT
# ...          ...        ...             ...         ...        ...
# 255965   3/31/17     394776      Laurel, MS         msa         MS
# 255966   3/31/17     395124  Starkville, MS         msa         MS
# 255967   3/31/17     394490    Columbus, MS         msa         MS
# 255968   3/31/17     394977    Picayune, MS         msa         MS
# 255969   3/31/17     394951      Oxford, MS         msa         MS
#
#         Home Value Index  Size Rank
# 0            206829.9543        236
# 1            209576.4668        236
# 2            212398.5270        236
# 3            215175.9703        236
# 4            217573.4558        236
# ...                  ...        ...
# 255965       107746.9037        434
# 255966       169984.2309        529
# 255967       125443.1976        543
# 255968       150324.7686        559
# 255969       215820.0045        564
#
# [255970 rows x 7 columns]

# %%
data = data[data['Region Name'] == 'Salt Lake City, UT']
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values('Date', inplace=True)
df = pd.DataFrame(data)
df
# Out:
#              Date  Region ID         Region Name Region Type State Name  \
# 163600 2000-01-31     395053  Salt Lake City, UT         msa         UT
# 163605 2000-02-29     395053  Salt Lake City, UT         msa         UT
# 163610 2000-03-31     395053  Salt Lake City, UT         msa         UT
# 163615 2000-04-30     395053  Salt Lake City, UT         msa         UT
# 163620 2000-05-31     395053  Salt Lake City, UT         msa         UT
# ...           ...        ...                 ...         ...        ...
# 165005 2023-06-30     395053  Salt Lake City, UT         msa         UT
# 165010 2023-07-31     395053  Salt Lake City, UT         msa         UT
# 165015 2023-08-31     395053  Salt Lake City, UT         msa         UT
# 165020 2023-09-30     395053  Salt Lake City, UT         msa         UT
# 165025 2023-10-31     395053  Salt Lake City, UT         msa         UT
#
#         Home Value Index  Size Rank
# 163600       173370.8057         48
# 163605       173473.7350         48
# 163610       173659.8637         48
# 163615       174086.9221         48
# 163620       175910.0283         48
# ...                  ...        ...
# 165005       524735.4525         48
# 165010       526616.8991         48
# 165015       528841.3976         48
# 165020       530407.2567         48
# 165025       531933.0192         48
#
# [286 rows x 7 columns]

# %%
df = df[['Date', 'Home Value Index']]
df
# Out:
#              Date  Home Value Index
# 163600 2000-01-31       173370.8057
# 163605 2000-02-29       173473.7350
# 163610 2000-03-31       173659.8637
# 163615 2000-04-30       174086.9221
# 163620 2000-05-31       175910.0283
# ...           ...               ...
# 165005 2023-06-30       524735.4525
# 165010 2023-07-31       526616.8991
# 165015 2023-08-31       528841.3976
# 165020 2023-09-30       530407.2567
# 165025 2023-10-31       531933.0192
#
# [286 rows x 2 columns]

# %%
# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)


# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(df)

# Splitting data into training and testing
train_size = int(len(scaled_data) * 0.9)
train, test = scaled_data[0:train_size,:], scaled_data[train_size:len(scaled_data),:]

# Function to create dataset for CNN
def create_dataset(dataset, look_back=1):
    X, Y = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), 0]
        X.append(a)
        Y.append(dataset[i + look_back, 0])
    return np.array(X), np.array(Y)

# Define look_back period
look_back = 3  # Increase this to at least 2 or more
X, Y = create_dataset(scaled_data, look_back)

# Reshape input to be [samples, time steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# Split into training and test sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[0:train_size,:,:], X[train_size:len(X),:,:]
Y_train, Y_test = Y[0:train_size], Y[train_size:len(Y)]

# %%
# Create the CNN model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=1, activation='relu', input_shape=(look_back, 1)))  # kernel_size reduced to 1
model.add(MaxPooling1D(pool_size=2))
model.add(Flatten())
model.add(Dense(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')


# Early stopping
early_stop = EarlyStopping(monitor='val_loss', patience=10)

# Train the model
model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=32, callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0205 - val_loss: 0.2989
# Epoch 2/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0085 - val_loss: 0.1783
# Epoch 3/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0047 - val_loss: 0.1052
# Epoch 4/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0039 - val_loss: 0.0787
# Epoch 5/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0031 - val_loss: 0.0659
# Epoch 6/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0023 - val_loss: 0.0575
# Epoch 7/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0016 - val_loss: 0.0347
# Epoch 8/100
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0011 - val_loss: 0.0255
# Epoch 9/100
# 8/8 [==============================] - 0s 2ms/step - loss: 6.9526e-04 - val_loss: 0.0180
# Epoch 10/100
# 8/8 [==============================] - 0s 2ms/step - loss: 4.3725e-04 - val_loss: 0.0117
# Epoch 11/100
# 8/8 [==============================] - 0s 2ms/step - loss: 2.6088e-04 - val_loss: 0.0064
# Epoch 12/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.6611e-04 - val_loss: 0.0035
# Epoch 13/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1806e-04 - val_loss: 0.0022
# Epoch 14/100
# 8/8 [==============================] - 0s 2ms/step - loss: 9.5205e-05 - val_loss: 0.0018
# Epoch 15/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9545e-05 - val_loss: 0.0013
# Epoch 16/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8224e-05 - val_loss: 0.0011
# Epoch 17/100
# 8/8 [==============================] - 0s 7ms/step - loss: 8.6970e-05 - val_loss: 0.0011
# Epoch 18/100
# 8/8 [==============================] - 0s 5ms/step - loss: 8.6665e-05 - val_loss: 0.0011
# Epoch 19/100
# 8/8 [==============================] - 0s 5ms/step - loss: 8.6599e-05 - val_loss: 0.0011
# Epoch 20/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6772e-05 - val_loss: 0.0012
# Epoch 21/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.5534e-05 - val_loss: 0.0014
# Epoch 22/100
# 8/8 [==============================] - 0s 2ms/step - loss: 9.6024e-05 - val_loss: 0.0014
# Epoch 23/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4308e-05 - val_loss: 0.0011
# Epoch 24/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.8021e-05 - val_loss: 0.0012
# Epoch 25/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6612e-05 - val_loss: 0.0012
# Epoch 26/100
# 8/8 [==============================] - 0s 4ms/step - loss: 8.4955e-05 - val_loss: 9.8249e-04
# Epoch 27/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6010e-05 - val_loss: 0.0011
# Epoch 28/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.5120e-05 - val_loss: 0.0011
# Epoch 29/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4775e-05 - val_loss: 0.0011
# Epoch 30/100
# 8/8 [==============================] - 0s 2ms/step - loss: 9.1468e-05 - val_loss: 0.0012
# Epoch 31/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6331e-05 - val_loss: 9.8081e-04
# Epoch 32/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4013e-05 - val_loss: 0.0011
# Epoch 33/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4194e-05 - val_loss: 0.0010
# Epoch 34/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.6035e-05 - val_loss: 9.9534e-04
# Epoch 35/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3687e-05 - val_loss: 0.0011
# Epoch 36/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4304e-05 - val_loss: 0.0010
# Epoch 37/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3565e-05 - val_loss: 0.0011
# Epoch 38/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3387e-05 - val_loss: 0.0011
# Epoch 39/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4984e-05 - val_loss: 0.0010
# Epoch 40/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.7414e-05 - val_loss: 9.3712e-04
# Epoch 41/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4233e-05 - val_loss: 0.0013
# Epoch 42/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.1831e-04 - val_loss: 0.0014
# Epoch 43/100
# 8/8 [==============================] - 0s 2ms/step - loss: 9.0291e-05 - val_loss: 0.0011
# Epoch 44/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0440e-04 - val_loss: 0.0011
# Epoch 45/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3821e-05 - val_loss: 0.0012
# Epoch 46/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4326e-05 - val_loss: 9.7167e-04
# Epoch 47/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4053e-05 - val_loss: 0.0011
# Epoch 48/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3280e-05 - val_loss: 9.9835e-04
# Epoch 49/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.4622e-05 - val_loss: 8.7617e-04
# Epoch 50/100
# 8/8 [==============================] - 0s 2ms/step - loss: 9.2479e-05 - val_loss: 0.0011
# Epoch 51/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3758e-05 - val_loss: 0.0012
# Epoch 52/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.2857e-05 - val_loss: 0.0012
# Epoch 53/100
# 8/8 [==============================] - 0s 2ms/step - loss: 1.0087e-04 - val_loss: 0.0014
# Epoch 54/100
# 8/8 [==============================] - 0s 2ms/step - loss: 9.1650e-05 - val_loss: 9.0955e-04
# Epoch 55/100
# 8/8 [==============================] - 0s 2ms/step - loss: 9.5924e-05 - val_loss: 9.4599e-04
# Epoch 56/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3616e-05 - val_loss: 0.0010
# Epoch 57/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3241e-05 - val_loss: 9.8458e-04
# Epoch 58/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.9628e-05 - val_loss: 0.0011
# Epoch 59/100
# 8/8 [==============================] - 0s 2ms/step - loss: 8.3942e-05 - val_loss: 0.0011

# %%
# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 8/8 [==============================] - 0s 456us/step
# 2/2 [==============================] - 0s 804us/step

# %%
# Invert predictions to original scale
train_predict = scaler.inverse_transform(train_predict)
Y_train_inv = scaler.inverse_transform([Y_train])
test_predict = scaler.inverse_transform(test_predict)
Y_test_inv = scaler.inverse_transform([Y_test])

# %%
# Calculate root mean squared error
train_rmse = np.sqrt(np.mean((train_predict[:,0] - Y_train_inv[0])**2))
test_rmse = np.sqrt(np.mean((test_predict[:,0] - Y_test_inv[0])**2))

print('Train RMSE:', train_rmse)
print('Test RMSE:', test_rmse)
# Out:
# Train RMSE: 3590.2598058674266
# Test RMSE: 13081.089580533218

# %%
# Assuming your train and test sets are split correctly
# Adjusting indices to match the length of the predictions

train_predict_length = len(train_predict)
test_predict_length = len(test_predict)

# Calculate the correct starting and ending indices
train_index_start = look_back
train_index_end = train_index_start + train_predict_length

test_index_start = train_size + look_back
test_index_end = test_index_start + test_predict_length

# Creating DataFrames with correct indices
train_predict_df = pd.DataFrame(train_predict, index=df.index[train_index_start:train_index_end], columns=['Predicted'])
train_actual_df = pd.DataFrame(Y_train_inv.T, index=df.index[train_index_start:train_index_end], columns=['Actual'])

test_predict_df = pd.DataFrame(test_predict, index=df.index[test_index_start:test_index_end], columns=['Predicted'])
test_actual_df = pd.DataFrame(Y_test_inv.T, index=df.index[test_index_start:test_index_end], columns=['Actual'])

# %%
# Plotting Train Data
plt.figure(figsize=(15, 6))
plt.plot(train_actual_df, label='Actual')
plt.plot(train_predict_df, label='Predicted')
plt.title('House Price Prediction - Training Data')
plt.xlabel('Date')
plt.ylabel('Home Value Index')
plt.legend()
plt.show()

# %%
# Plotting Test Data
plt.figure(figsize=(15, 6))
plt.plot(test_actual_df, label='Actual')
plt.plot(test_predict_df, label='Predicted')
plt.title('House Price Prediction - Testing Data')
plt.xlabel('Date')
plt.ylabel('Home Value Index')
plt.legend()
plt.show()

# %%
future_months = 12
future_predictions = []
current_input = scaled_data[-look_back:]  # Start with the last known data

for _ in range(future_months):
    # Reshape input for the model
    reshaped_input = current_input.reshape((1, look_back, 1))
    
    # Predict the next step
    next_prediction = model.predict(reshaped_input)

    # Append the prediction to the list
    future_predictions.append(next_prediction[0, 0])
    
    # Update the input sequence
    # Ensure that both parts have the same number of dimensions
    next_prediction_reshaped = np.array([next_prediction[0, 0]]).reshape(1, -1)
    current_input = np.append(current_input[1:], next_prediction_reshaped, axis=0)

# Inverse transform to get actual value predictions
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# Adjust the date generation to reflect monthly steps
last_date = df.index[-1]
prediction_dates = pd.date_range(start=last_date, periods=future_months, freq='MS')
future_df = pd.DataFrame(future_predictions, index=prediction_dates, columns=['Predicted Future Value'])

print(future_df)
# Out:
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 7ms/step
#             Predicted Future Value
# 2023-11-01            524457.43750
# 2023-12-01            525905.81250
# 2024-01-01            525905.81250
# 2024-02-01            520184.12500
# 2024-03-01            520184.12500
# 2024-04-01            520184.12500
# 2024-05-01            514752.43750
# 2024-06-01            514752.43750
# 2024-07-01            514752.43750
# 2024-08-01            509596.03125
# 2024-09-01            509596.03125
# 2024-10-01            509596.03125

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Plotting Test Data and Future Predictions
plt.figure(figsize=(30, 20))

# Plot actual and predicted test data
plt.plot(test_actual_df, label='Actual Test Data', color='blue')
plt.plot(test_predict_df, label='Predicted Test Data', color='orange')

# Plot future predictions
plt.plot(future_df, label='Future Predictions', color='green', linestyle='dashed')

# Formatting the x-axis to show month and year
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
plt.gcf().autofmt_xdate()  # Rotate date labels

plt.title('House Price Prediction - Test Data and Future Predictions')
plt.xlabel('Date (Month-Year)')
plt.ylabel('Home Value Index')
plt.legend()
plt.show()
